# %%
from pycaret.regression import *
import pandas as pd
import matplotlib.pyplot as plt
from functions import accuracy
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
df_raw = pd.read_csv('kastom_filled.csv', parse_dates=[0], index_col=0)
df = df_raw.copy()[:2000]
df
# Out:
#                      Temp (C)  Humidity (%)  PM10 (ug/m3)  PM2.5 (ug/m3)  \
# 2022-04-10 00:00:00     18.32         58.78          39.0           23.0
# 2022-04-10 01:00:00     16.80         60.04          33.5           20.0
# 2022-04-10 02:00:00     16.10         58.67          22.0           13.0
# 2022-04-10 03:00:00     16.63         56.95          30.5           19.0
# 2022-04-10 04:00:00     17.07         54.34          29.0           18.0
# ...                       ...           ...           ...            ...
# 2022-07-02 05:00:00     26.43         70.12          74.5           45.5
# 2022-07-02 06:00:00     27.25         68.30          89.5           55.0
# 2022-07-02 07:00:00     28.55         65.79          86.0           52.0
# 2022-07-02 08:00:00     31.58         52.04          74.5           45.0
# 2022-07-02 09:00:00     31.64         58.41          76.0           46.5
#
#                      PM1 (ug/m3)  NO2 (ppb)  CO (μg/m3 10²)
# 2022-04-10 00:00:00         10.0      61.64           92.88
# 2022-04-10 01:00:00          9.0      58.22           49.21
# 2022-04-10 02:00:00          5.0      58.22           37.32
# 2022-04-10 03:00:00          8.0      61.64           48.01
# 2022-04-10 04:00:00          7.0      58.22           46.49
# ...                          ...        ...             ...
# 2022-07-02 05:00:00         19.0      58.22           60.92
# 2022-07-02 06:00:00         23.0      53.08           54.43
# 2022-07-02 07:00:00         22.0      46.23           48.53
# 2022-07-02 08:00:00         19.5      20.89           37.80
# 2022-07-02 09:00:00         20.0      40.75           44.16
#
# [2000 rows x 7 columns]

# %%
target = 'CO (μg/m3 10²)'
ignore_list = ['PM1 (ug/m3)', 'PM10 (ug/m3)'] if target=='PM2.5 (ug/m3)' else []

steps = 7*24
train = df[:-steps]
test = df[-steps:]

numeric_features = df.columns.drop(target).to_list()

# %%
s = setup(data=train, test_data=test, target=target, fold_strategy='timeseries',
          numeric_features=numeric_features, ignore_features=ignore_list,
          fold=10,silent=True, session_id=123, verbose=0)

# %% [markdown]
# ### Training and Validation of various models

# %%
comparison = compare_models()
# Out:
# <style type="text/css">
# #T_5701e th {
#   text-align: left;
# }
# #T_5701e_row0_col0, #T_5701e_row0_col2, #T_5701e_row0_col3, #T_5701e_row1_col0, #T_5701e_row1_col1, #T_5701e_row1_col2, #T_5701e_row1_col4, #T_5701e_row1_col5, #T_5701e_row1_col6, #T_5701e_row2_col0, #T_5701e_row2_col1, #T_5701e_row2_col2, #T_5701e_row2_col3, #T_5701e_row2_col4, #T_5701e_row2_col5, #T_5701e_row2_col6, #T_5701e_row3_col0, #T_5701e_row3_col1, #T_5701e_row3_col2, #T_5701e_row3_col3, #T_5701e_row3_col4, #T_5701e_row3_col5, #T_5701e_row3_col6, #T_5701e_row4_col0, #T_5701e_row4_col1, #T_5701e_row4_col2, #T_5701e_row4_col3, #T_5701e_row4_col4, #T_5701e_row4_col5, #T_5701e_row4_col6, #T_5701e_row5_col0, #T_5701e_row5_col1, #T_5701e_row5_col2, #T_5701e_row5_col3, #T_5701e_row5_col4, #T_5701e_row5_col5, #T_5701e_row5_col6, #T_5701e_row6_col0, #T_5701e_row6_col1, #T_5701e_row6_col2, #T_5701e_row6_col3, #T_5701e_row6_col4, #T_5701e_row6_col5, #T_5701e_row6_col6, #T_5701e_row7_col0, #T_5701e_row7_col1, #T_5701e_row7_col3, #T_5701e_row7_col4, #T_5701e_row7_col5, #T_5701e_row7_col6, #T_5701e_row8_col0, #T_5701e_row8_col1, #T_5701e_row8_col2, #T_5701e_row8_col3, #T_5701e_row8_col4, #T_5701e_row8_col5, #T_5701e_row8_col6, #T_5701e_row9_col0, #T_5701e_row9_col1, #T_5701e_row9_col2, #T_5701e_row9_col3, #T_5701e_row9_col4, #T_5701e_row9_col5, #T_5701e_row9_col6, #T_5701e_row10_col0, #T_5701e_row10_col1, #T_5701e_row10_col2, #T_5701e_row10_col3, #T_5701e_row10_col4, #T_5701e_row10_col5, #T_5701e_row10_col6, #T_5701e_row11_col0, #T_5701e_row11_col1, #T_5701e_row11_col2, #T_5701e_row11_col3, #T_5701e_row11_col4, #T_5701e_row11_col5, #T_5701e_row11_col6, #T_5701e_row12_col0, #T_5701e_row12_col1, #T_5701e_row12_col2, #T_5701e_row12_col3, #T_5701e_row12_col4, #T_5701e_row12_col5, #T_5701e_row12_col6, #T_5701e_row13_col0, #T_5701e_row13_col1, #T_5701e_row13_col2, #T_5701e_row13_col3, #T_5701e_row13_col4, #T_5701e_row13_col5, #T_5701e_row13_col6, #T_5701e_row14_col0, #T_5701e_row14_col1, #T_5701e_row14_col2, #T_5701e_row14_col3, #T_5701e_row14_col4, #T_5701e_row14_col5, #T_5701e_row14_col6, #T_5701e_row15_col0, #T_5701e_row15_col1, #T_5701e_row15_col2, #T_5701e_row15_col3, #T_5701e_row15_col4, #T_5701e_row15_col5, #T_5701e_row15_col6, #T_5701e_row16_col0, #T_5701e_row16_col1, #T_5701e_row16_col2, #T_5701e_row16_col3, #T_5701e_row16_col4, #T_5701e_row16_col5, #T_5701e_row16_col6, #T_5701e_row17_col0, #T_5701e_row17_col1, #T_5701e_row17_col2, #T_5701e_row17_col3, #T_5701e_row17_col4, #T_5701e_row17_col5, #T_5701e_row17_col6 {
#   text-align: left;
# }
# #T_5701e_row0_col1, #T_5701e_row0_col4, #T_5701e_row0_col5, #T_5701e_row0_col6, #T_5701e_row1_col3, #T_5701e_row7_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5701e_row0_col7, #T_5701e_row1_col7, #T_5701e_row2_col7, #T_5701e_row4_col7, #T_5701e_row5_col7, #T_5701e_row6_col7, #T_5701e_row7_col7, #T_5701e_row8_col7, #T_5701e_row9_col7, #T_5701e_row10_col7, #T_5701e_row11_col7, #T_5701e_row12_col7, #T_5701e_row14_col7, #T_5701e_row15_col7, #T_5701e_row16_col7, #T_5701e_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5701e_row3_col7, #T_5701e_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5701e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5701e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5701e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5701e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5701e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5701e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5701e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5701e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5701e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5701e_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_5701e_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_5701e_row0_col1" class="data row0 col1" >10.2595</td>
#       <td id="T_5701e_row0_col2" class="data row0 col2" >200.2807</td>
#       <td id="T_5701e_row0_col3" class="data row0 col3" >13.9565</td>
#       <td id="T_5701e_row0_col4" class="data row0 col4" >0.2898</td>
#       <td id="T_5701e_row0_col5" class="data row0 col5" >0.2847</td>
#       <td id="T_5701e_row0_col6" class="data row0 col6" >0.2689</td>
#       <td id="T_5701e_row0_col7" class="data row0 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_5701e_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_5701e_row1_col1" class="data row1 col1" >10.5238</td>
#       <td id="T_5701e_row1_col2" class="data row1 col2" >200.1304</td>
#       <td id="T_5701e_row1_col3" class="data row1 col3" >13.9558</td>
#       <td id="T_5701e_row1_col4" class="data row1 col4" >0.2787</td>
#       <td id="T_5701e_row1_col5" class="data row1 col5" >0.3086</td>
#       <td id="T_5701e_row1_col6" class="data row1 col6" >0.2757</td>
#       <td id="T_5701e_row1_col7" class="data row1 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_5701e_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_5701e_row2_col1" class="data row2 col1" >10.5408</td>
#       <td id="T_5701e_row2_col2" class="data row2 col2" >200.8166</td>
#       <td id="T_5701e_row2_col3" class="data row2 col3" >13.9785</td>
#       <td id="T_5701e_row2_col4" class="data row2 col4" >0.2751</td>
#       <td id="T_5701e_row2_col5" class="data row2 col5" >0.3091</td>
#       <td id="T_5701e_row2_col6" class="data row2 col6" >0.2759</td>
#       <td id="T_5701e_row2_col7" class="data row2 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_5701e_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_5701e_row3_col1" class="data row3 col1" >10.5438</td>
#       <td id="T_5701e_row3_col2" class="data row3 col2" >201.1281</td>
#       <td id="T_5701e_row3_col3" class="data row3 col3" >13.9893</td>
#       <td id="T_5701e_row3_col4" class="data row3 col4" >0.2737</td>
#       <td id="T_5701e_row3_col5" class="data row3 col5" >0.3090</td>
#       <td id="T_5701e_row3_col6" class="data row3 col6" >0.2758</td>
#       <td id="T_5701e_row3_col7" class="data row3 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_5701e_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_5701e_row4_col1" class="data row4 col1" >10.5759</td>
#       <td id="T_5701e_row4_col2" class="data row4 col2" >201.4167</td>
#       <td id="T_5701e_row4_col3" class="data row4 col3" >13.9999</td>
#       <td id="T_5701e_row4_col4" class="data row4 col4" >0.2711</td>
#       <td id="T_5701e_row4_col5" class="data row4 col5" >0.3104</td>
#       <td id="T_5701e_row4_col6" class="data row4 col6" >0.2778</td>
#       <td id="T_5701e_row4_col7" class="data row4 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_5701e_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_5701e_row5_col1" class="data row5 col1" >10.5757</td>
#       <td id="T_5701e_row5_col2" class="data row5 col2" >201.4112</td>
#       <td id="T_5701e_row5_col3" class="data row5 col3" >13.9997</td>
#       <td id="T_5701e_row5_col4" class="data row5 col4" >0.2711</td>
#       <td id="T_5701e_row5_col5" class="data row5 col5" >0.3104</td>
#       <td id="T_5701e_row5_col6" class="data row5 col6" >0.2778</td>
#       <td id="T_5701e_row5_col7" class="data row5 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_5701e_level0_row6" class="row_heading level

# %% [markdown]
# ### Επιλογή Random Forest (αποδεκτές επιδόσεις, δοκιμασμένος στη βιβλιογραφία)

# %%
model = create_model('rf')
# Out:
# <style type="text/css">
# #T_72021_row10_col0, #T_72021_row10_col1, #T_72021_row10_col2, #T_72021_row10_col3, #T_72021_row10_col4, #T_72021_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_72021">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72021_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72021_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72021_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72021_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72021_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_72021_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72021_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72021_row0_col0" class="data row0 col0" >11.0663</td>
#       <td id="T_72021_row0_col1" class="data row0 col1" >228.0354</td>
#       <td id="T_72021_row0_col2" class="data row0 col2" >15.1008</td>
#       <td id="T_72021_row0_col3" class="data row0 col3" >-0.2997</td>
#       <td id="T_72021_row0_col4" class="data row0 col4" >0.3107</td>
#       <td id="T_72021_row0_col5" class="data row0 col5" >0.2963</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72021_row1_col0" class="data row1 col0" >9.8761</td>
#       <td id="T_72021_row1_col1" class="data row1 col1" >196.6750</td>
#       <td id="T_72021_row1_col2" class="data row1 col2" >14.0241</td>
#       <td id="T_72021_row1_col3" class="data row1 col3" >0.1667</td>
#       <td id="T_72021_row1_col4" class="data row1 col4" >0.2769</td>
#       <td id="T_72021_row1_col5" class="data row1 col5" >0.2289</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72021_row2_col0" class="data row2 col0" >8.9679</td>
#       <td id="T_72021_row2_col1" class="data row2 col1" >138.5862</td>
#       <td id="T_72021_row2_col2" class="data row2 col2" >11.7723</td>
#       <td id="T_72021_row2_col3" class="data row2 col3" >0.3442</td>
#       <td id="T_72021_row2_col4" class="data row2 col4" >0.2686</td>
#       <td id="T_72021_row2_col5" class="data row2 col5" >0.2418</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72021_row3_col0" class="data row3 col0" >9.5938</td>
#       <td id="T_72021_row3_col1" class="data row3 col1" >202.5772</td>
#       <td id="T_72021_row3_col2" class="data row3 col2" >14.2330</td>
#       <td id="T_72021_row3_col3" class="data row3 col3" >0.3281</td>
#       <td id="T_72021_row3_col4" class="data row3 col4" >0.2439</td>
#       <td id="T_72021_row3_col5" class="data row3 col5" >0.1723</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72021_row4_col0" class="data row4 col0" >9.0421</td>
#       <td id="T_72021_row4_col1" class="data row4 col1" >136.3368</td>
#       <td id="T_72021_row4_col2" class="data row4 col2" >11.6763</td>
#       <td id="T_72021_row4_col3" class="data row4 col3" >0.5623</td>
#       <td id="T_72021_row4_col4" class="data row4 col4" >0.2419</td>
#       <td id="T_72021_row4_col5" class="data row4 col5" >0.2098</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72021_row5_col0" class="data row5 col0" >12.2195</td>
#       <td id="T_72021_row5_col1" class="data row5 col1" >265.1618</td>
#       <td id="T_72021_row5_col2" class="data row5 col2" >16.2838</td>
#       <td id="T_72021_row5_col3" class="data row5 col3" >0.2278</td>
#       <td id="T_72021_row5_col4" class="data row5 col4" >0.2753</td>
#       <td id="T_72021_row5_col5" class="data row5 col5" >0.2234</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72021_row6_col0" class="data row6 col0" >10.0231</td>
#       <td id="T_72021_row6_col1" class="data row6 col1" >186.6466</td>
#       <td id="T_72021_row6_col2" class="data row6 col2" >13.6619</td>
#       <td id="T_72021_row6_col3" class="data row6 col3" >0.3144</td>
#       <td id="T_72021_row6_col4" class="data row6 col4" >0.2570</td>
#       <td id="T_72021_row6_col5" class="data row6 col5" >0.2163</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72021_row7_col0" class="data row7 col0" >9.9437</td>
#       <td id="T_72021_row7_col1" class="data row7 col1" >165.4709</td>
#       <td id="T_72021_row7_col2" class="data row7 col2" >12.8635</td>
#       <td id="T_72021_row7_col3" class="data row7 col3" >0.1730</td>
#       <td id="T_72021_row7_col4" class="data row7 col4" >0.4114</td>
#       <td id="T_72021_row7_col5" class="data row7 col5" >0.8495</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72021_row8_col0" class="data row8 col0" >12.1774</td>
#       <td id="T_72021_row8_col1" class="data row8 col1" >278.8585</td>
#       <td id="T_72021_row8_col2" class="data row8 col2" >16.6991</td>
#       <td id="T_72021_row8_col3" class="data row8 col3" >0.4345</td>
#       <td id="T_72021_row8_col4" class="data row8 col4" >0.3236</td>
#       <td id="T_72021_row8_col5" class="data row8 col5" >0.2982</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72021_row9_col0" class="data row9 col0" >10.1927</td>
#       <td id="T_72021_row9_col1" class="data row9 col1" >192.4962</td>
#       <td id="T_72021_row9_col2" class="data row9 col2" >13.8743</td>
#       <td id="T_72021_row9_col3" class="data row9 col3" >0.4128</td>
#       <td id="T_72021_row9_col4" class="data row9 col4" >0.2813</td>
#       <td id="T_72021_row9_col5" class="data row9 col5" >0.2376</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_72021_row10_col0" class="data row10 col0" >10.3103</td>
#       <td id="T_72021_row10_col1" class="data row10 col1" >199.0845</td>
#       <td id="T_72021_row10_col2" class="data row10 col2" >14.0189</td>
#       <td id="T_72021_row10_col3" class="data row10 col3" >0.2664</td>
#       <td id="T_72021_row10_col4" class="data row10 col4" >0.2891</td>
#       <td id="T_72021_row10_col5" class="data row10 col5" >0.2974</td>
#     </tr>
#     <tr>
#       <th id="T_72021_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_72021_row11_col0" class="data row11 col0" >1.0975</td>
#       <td id="T_72021_row11_col1" class="data row11 col1" >45.2897</td>
#       <td id="T_72021_row11_col2" class="data row11 col2" >1.5984</td>
#       <td id="T_72021_row11_col3" class="data row11 col3" >0.2214</td>
#       <td id="T_72021_row11_col4" class="data row11 col4" >0.0477</td>
#       <td id="T_72021_row11_col5" class="data row11 col5" >0.1875</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Πρόβλεψη NO2

# %%
predictions = predict_model(model, data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3653e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3653e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3653e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3653e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3653e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3653e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3653e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3653e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3653e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3653e_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_3653e_row0_col1" class="data row0 col1" >7.7984</td>
#       <td id="T_3653e_row0_col2" class="data row0 col2" >94.0994</td>
#       <td id="T_3653e_row0_col3" class="data row0 col3" >9.7005</td>
#       <td id="T_3653e_row0_col4" class="data row0 col4" >0.4139</td>
#       <td id="T_3653e_row0_col5" class="data row0 col5" >0.2285</td>
#       <td id="T_3653e_row0_col6" class="data row0 col6" >0.2064</td>
#     </tr>
#   </tbody>
# </table>

# %%
errors_list = [mean_absolute_error(predictions[target], predictions.Label),
               mean_squared_error(predictions[target], predictions.Label),
              accuracy(predictions[target], predictions.Label)['mape'],
              r2_score(predictions[target], predictions.Label)]

errors_series = pd.Series(errors_list, index=['MAE','MSE','MAPE','R2'])
target_name = 'PM2.5' if target=='PM2.5 (ug/m3)' else 'CO' if target=='CO (μg/m3 10²)' else target
errors_series.to_csv(f'{target_name}_rf_metrics.csv')
print(errors_series.round(3))
# Out:
# MAE      7.798
# MSE     94.099
# MAPE     0.176
# R2       0.414
# dtype: float64

# %%
plt.style.use('seaborn-poster')
predictions[[target, 'Label']].plot(figsize=(14,5))
plt.legend([f'Actual {target_name}', f'Predicted {target_name}'])
plt.title(f"Random Forest model for {target_name}")
plt.savefig(f"Plots/rf/{target_name}rf.png")
plt.show()

# %%
plot_model(model, plot='feature', save=True)
# Out:
# 'Feature Importance.png'

# %%
plot_model(model, plot='feature')
