# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df = pd.read_csv('kunak_filled.csv', parse_dates=[0], index_col=0).resample('D').mean()

# %%
df[:] = StandardScaler().fit_transform(df)

# %%
tsne = TSNE(perplexity=20, n_iter=2000, verbose=1, random_state=0)
tsne_results = tsne.fit_transform(df)
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 101 samples in 0.001s...
# [t-SNE] Computed neighbors for 101 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 101 / 101
# [t-SNE] Mean sigma: 1.336654
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.305214
# [t-SNE] KL divergence after 1450 iterations: 0.341384

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=tsne_results[:,0], y=tsne_results[:,1] )
plt.show()

# %% [markdown]
# Να το δοκιμάσω σε 3D
