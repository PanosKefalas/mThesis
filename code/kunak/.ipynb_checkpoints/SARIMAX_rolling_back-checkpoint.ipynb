# %% [markdown]
# ### Σταδιακή αύξηση του δείγματος κατά 2 εβδομάδες και αξιολόγηση πρόγνωσης μοντέλου SARIMAX

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error, r2_score, mean_squared_error

# %%
df_raw = pd.read_csv('kunak_filled.csv', parse_dates=[0], index_col=0)
df=df_raw.asfreq('H')

# %%
week = 24*7
step = 0
date_to = week*4
errors = {}

# %%
while (step+date_to)<=(df.shape[0]):
 
    sample = df[-date_to-step:].copy()
    
    target = 'NO2 (ppb)'
    
    train = sample[:-week]
    test = sample[-week:]
    
    train_y, train_X = train[target], train.drop(columns=[target, 'PM1 (ug/m3)', 'PM2.5 (ug/m3)','PM10 (ug/m3)', 'Temp (C)'])
    test_y, test_X = test[target], test.drop(columns=[target, 'PM1 (ug/m3)', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'Temp (C)'])
    
    p,d,q = 1,1,1
    P,D,Q,m = 1,0,1,24
    
    sarimax_model = ARIMA(endog=train_y, exog=train_X, order=(p,d,q), seasonal_order=(P,D,Q, m))
    sarimax_results = sarimax_model.fit(method_kwargs={"warn_convergence": False})
    
    prediction_steps = 24*3
    predictions = sarimax_results.get_forecast(prediction_steps, exog=test_X[:prediction_steps])
    
    predicted_values_sarimax = predictions.summary_frame()['mean']
    actual = test_y[:prediction_steps]
    
    errors_list = [mean_absolute_error(predicted_values_sarimax, actual),
                   mean_squared_error(predicted_values_sarimax, actual),
                   mean_absolute_percentage_error(predicted_values_sarimax, actual),
                   r2_score(predicted_values_sarimax, actual)]
 
    errors[str(df.index[-date_to-step].date())] = errors_list
    step += week

# %%
errors_df = pd.DataFrame(errors).T.round(2)
errors_df.columns=['MAE', 'MSE', 'MAPE', 'R2']
errors_df.index = pd.to_datetime(errors_df.index)
errors_df.to_csv(f"Plots/sarimax/{target}rolling_back.csv")
errors_df
# Out:
#              MAE    MSE  MAPE    R2
# 2022-08-08  3.38  15.69  0.07  0.82
# 2022-08-01  3.44  15.82  0.07  0.82
# 2022-07-25  3.44  15.82  0.07  0.82
# 2022-07-18  3.21  14.35  0.07  0.84
# 2022-07-11  3.61  17.37  0.08  0.80
# 2022-07-04  3.88  19.53  0.08  0.77
# 2022-06-27  3.65  17.64  0.08  0.80
# 2022-06-20  3.77  18.68  0.08  0.77
# 2022-06-13  3.79  18.72  0.08  0.77
# 2022-06-06  3.85  19.12  0.08  0.77
# 2022-05-30  3.58  16.94  0.07  0.80
# 2022-05-23  3.70  18.07  0.08  0.78
# 2022-05-16  3.59  17.15  0.08  0.80
# 2022-05-09  3.33  15.24  0.07  0.83
# 2022-05-02  3.34  15.19  0.07  0.83
# 2022-04-25  3.38  15.53  0.07  0.82
# 2022-04-18  3.47  16.27  0.07  0.81
# 2022-04-11  3.77  19.12  0.08  0.76

# %%
plt.style.use('seaborn-poster')
errors_df_scaled = errors_df.copy()
errors_df_scaled.iloc[:,1] = errors_df_scaled['MSE']/10
errors_df_scaled.iloc[:,2] = errors_df_scaled['MAPE']*10
errors_df_scaled.iloc[:,3] = errors_df_scaled['R2']*10
errors_df_scaled.drop(['MAPE'], axis=1).plot(figsize=(16,4), x_compat=True)
plt.yticks([])
plt.xticks(errors_df.index)
plt.title(f"SARIMAX increasing sample errors for {target} forecast")
plt.tight_layout()
plt.savefig(f"Plots/sarimax/{target}rolling_back.png")
plt.show()
