# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
kunak = pd.read_csv('kunak_filled.csv', parse_dates=[0], index_col=0)
wind = pd.read_csv('wind.csv', parse_dates=[0], index_col=0)

# %%
df = pd.concat([kunak, wind],axis=1, join='inner')
df
# Out:
#                      Dew Point (C)  H2S (ppb)  Humidity (%)  NO2 (ppb)  \
# 2022-05-13 12:00:00          11.56       1.14         34.93       4.54
# 2022-05-13 13:00:00          12.77       2.72         36.15       3.82
# 2022-05-13 14:00:00          12.20       3.20         34.29       3.59
# 2022-05-13 15:00:00           9.27       0.06         28.25       0.77
# 2022-05-13 16:00:00           9.24       0.31         27.71       1.52
# ...                            ...        ...           ...        ...
# 2022-07-19 12:00:00          15.60       0.00         41.74       2.64
# 2022-07-19 13:00:00          16.67       3.50         43.83      13.48
# 2022-07-19 14:00:00          17.14       3.25         44.70      11.90
# 2022-07-19 15:00:00          17.09       0.29         40.17       6.50
# 2022-07-19 16:00:00          17.86       5.68         41.35      11.30
#
#                      O3 (ppb)  Pressure (hPa)  TSP (ug/m3)  Temp (C)  \
# 2022-05-13 12:00:00     39.70         1015.66        18.97     28.57
# 2022-05-13 13:00:00     51.90         1015.12        16.63     29.34
# 2022-05-13 14:00:00     52.35         1014.26        14.34     29.66
# 2022-05-13 15:00:00     56.88         1013.60        14.95     29.59
# 2022-05-13 16:00:00     61.56         1012.83        14.36     29.88
# ...                       ...             ...          ...       ...
# 2022-07-19 12:00:00     63.44         1017.23        19.29     30.04
# 2022-07-19 13:00:00     62.59         1016.84        24.59     30.38
# 2022-07-19 14:00:00     67.56         1016.27        15.83     30.53
# 2022-07-19 15:00:00     71.55         1015.60        16.10     32.35
# 2022-07-19 16:00:00     71.15         1015.08        15.57     32.71
#
#                      windspeed  direction
# 2022-05-13 12:00:00       1.46      68.00
# 2022-05-13 13:00:00       2.98      72.62
# 2022-05-13 14:00:00       5.81      71.18
# 2022-05-13 15:00:00       6.98      57.97
# 2022-05-13 16:00:00       6.23      56.73
# ...                        ...        ...
# 2022-07-19 12:00:00       4.70      69.47
# 2022-07-19 13:00:00       4.81      61.27
# 2022-07-19 14:00:00       5.83      71.08
# 2022-07-19 15:00:00       5.33      72.22
# 2022-07-19 16:00:00       6.08      71.67
#
# [1329 rows x 10 columns]

# %%
plt.figure(figsize=(8,2))
sns.heatmap(df.corr()[['windspeed','direction']].T,cmap='crest', annot=True, square=True)
plt.show()

# %% [markdown]
# #### Δεν υφίσταται συσχέτιση κατεύθυνσης σε μοίρες.

# %%
bins = bins = np.linspace(0,360,9)+22.5
bins = np.insert(bins,0,0)
labels = ["N","NE","E","SE","S","SW","W","NW","N2"]

# %%
df['wind direction'] = pd.cut(df.direction, bins=bins, labels=labels, include_lowest=True)
df['wind direction'] = df['wind direction'].replace('N2','N')
df.head()
# Out:
#                      Dew Point (C)  H2S (ppb)  Humidity (%)  NO2 (ppb)  \
# 2022-05-13 12:00:00          11.56       1.14         34.93       4.54
# 2022-05-13 13:00:00          12.77       2.72         36.15       3.82
# 2022-05-13 14:00:00          12.20       3.20         34.29       3.59
# 2022-05-13 15:00:00           9.27       0.06         28.25       0.77
# 2022-05-13 16:00:00           9.24       0.31         27.71       1.52
#
#                      O3 (ppb)  Pressure (hPa)  TSP (ug/m3)  Temp (C)  \
# 2022-05-13 12:00:00     39.70         1015.66        18.97     28.57
# 2022-05-13 13:00:00     51.90         1015.12        16.63     29.34
# 2022-05-13 14:00:00     52.35         1014.26        14.34     29.66
# 2022-05-13 15:00:00     56.88         1013.60        14.95     29.59
# 2022-05-13 16:00:00     61.56         1012.83        14.36     29.88
#
#                      windspeed  direction wind direction
# 2022-05-13 12:00:00       1.46      68.00              E
# 2022-05-13 13:00:00       2.98      72.62              E
# 2022-05-13 14:00:00       5.81      71.18              E
# 2022-05-13 15:00:00       6.98      57.97             NE
# 2022-05-13 16:00:00       6.23      56.73             NE

# %%
df['wind direction']=df['wind direction'].astype('string')
df.loc[df['windspeed']<0.5,'wind direction'] = 'CALM'

# %%
df.to_csv('kunak_wind.csv')
