# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

# %% [markdown]
# ### Συσταδοποίηση ημερήσιων μέσων

# %%
kunak = pd.read_csv('kunak_filled.csv', parse_dates=[0], index_col=0).resample('D').mean()

# %%
pollutants = kunak[['H2S (ppb)','NO2 (ppb)', 'O3 (ppb)', 'PM2.5 (ug/m3)']]

# %%
scaler = MinMaxScaler()
pollutants_scaled = pollutants.copy()
pollutants_scaled[:] = scaler.fit_transform(pollutants)

# %%
pca = PCA(3)
pollutants_pca = pca.fit_transform(pollutants_scaled)
print(pca.n_components_)
# Out:
# 3

# %%
n_pcs = pca.n_components_
important = [np.abs(pca.components_)[i].argmax() for i in range(n_pcs)]
names = pollutants.columns
important_features = [names[important[i]] for i in range(n_pcs)]
print(important_features)
# Out:
# ['NO2 (ppb)', 'H2S (ppb)', 'O3 (ppb)']

# %%
inertias = []
for k in range(2,10):
    kmeans = KMeans(k)
    kmeans.fit(pollutants_pca)
    inertias.append(kmeans.inertia_)

# %%
plt.plot(np.arange(2,10), inertias)
plt.title("Elbow method")
plt.ylabel("Inertia")
plt.xlabel("k number of clusters")
plt.xticks(np.arange(2,10))
plt.grid()
plt.savefig("Plots/kmeans/elbow.png")
plt.show()

# %%
kmeans = KMeans(4)
kmeans.fit(pollutants_pca)
# Out:
# KMeans(n_clusters=4)

# %%
kunak_clustered = kunak.copy()
kunak_clustered['PC1'] = pollutants_pca[:,0]
kunak_clustered['PC2'] = pollutants_pca[:,1]
kunak_clustered['PC3'] = pollutants_pca[:,2]
kunak_clustered['Cluster'] = kmeans.labels_

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')
ax.scatter(kunak_clustered['PC1'], kunak_clustered['PC2'], kunak_clustered['PC3'])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')

plt.title("3D PCA visualization")
plt.savefig("Plots/kmeans/pca.png")
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')

for cluster in np.sort(kunak_clustered.Cluster.unique()):
    ax.scatter(kunak_clustered['PC1'][kunak_clustered.Cluster==cluster], 
               kunak_clustered['PC2'][kunak_clustered.Cluster==cluster], 
               kunak_clustered['PC3'][kunak_clustered.Cluster==cluster], 
               edgecolor='black', s=80,
               label=f'Cluster {cluster}')
    ax.legend()
    
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')
ax.scatter(kunak_clustered['PC1'], kunak_clustered['PC2'], kunak_clustered['PC3'], edgecolor='black', c=kunak_clustered['Cluster'], s=80, cmap='viridis_r')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')

plt.title("3D K-Means clustering visualization")
plt.savefig("Plots/kmeans/clusters.png")
plt.show()

# %%
profiles = round(kunak_clustered.drop(columns=['PC1','PC2','Dew Point (C)','Temp (C)','Humidity (%)','PM1 (ug/m3)','PM10 (ug/m3)',]),0)
profiles
# Out:
#             H2S (ppb)  NO2 (ppb)  O3 (ppb)  PM2.5 (ug/m3)  PC3  Cluster
# Datetime
# 2022-04-10        7.0       53.0      24.0            5.0 -0.0        1
# 2022-04-11        1.0       36.0      48.0            5.0 -0.0        0
# 2022-04-12        6.0       34.0      37.0            4.0 -0.0        0
# 2022-04-13        4.0       54.0      28.0            5.0 -0.0        1
# 2022-04-14        7.0       60.0      24.0            9.0 -0.0        1
# ...               ...        ...       ...            ...  ...      ...
# 2022-08-31       14.0       44.0      42.0           11.0  0.0        3
# 2022-09-01       14.0       56.0      38.0           14.0  0.0        3
# 2022-09-02        9.0       74.0      31.0           11.0  0.0        1
# 2022-09-03        8.0       59.0      34.0            9.0 -0.0        1
# 2022-09-04       11.0       59.0      38.0            9.0  0.0        3
#
# [148 rows x 6 columns]

# %%
sns.set_style('whitegrid')
sns.set_palette("deep")
fig, ax = plt.subplots(2,2, figsize=(10,8))

sns.boxplot(data=profiles.loc[profiles['Cluster']==0].drop(columns='Cluster'), ax=ax[0,0])
sns.boxplot(data=profiles.loc[profiles['Cluster']==1].drop(columns='Cluster'), ax=ax[0,1])
sns.boxplot(data=profiles.loc[profiles['Cluster']==2].drop(columns='Cluster'), ax=ax[1,0])
sns.boxplot(data=profiles.loc[profiles['Cluster']==3].drop(columns='Cluster'), ax=ax[1,1])

ax[0,0].set_title('Cluster 0')
ax[0,1].set_title('Cluster 1')
ax[1,0].set_title('Cluster 3')
ax[1,1].set_title('Cluster 4')

ax[0,0].set_ylim((0,90))
ax[0,1].set_ylim((0,90))
ax[1,0].set_ylim((0,90))
ax[1,1].set_ylim((0,90))

plt.tight_layout()
plt.suptitle("K-Means Daily profile clustering", fontsize=14, y=1.02)
plt.savefig("Plots/kmeans/profiles.png")
plt.show()

# %%
profiles['Cluster'].value_counts().plot(kind='pie',autopct='%1.1f%%', figsize=(6,6), fontsize=18)
plt.title('Cluster Frequency', fontsize=18)
plt.ylabel("")
plt.savefig("Plots/kmeans/freq.png")
plt.show()
